# %% [markdown]
# Using Tensorflow backend

# %%
# Load various imports 
from datetime import datetime
from os import listdir
from os.path import isfile, join

import librosa
import librosa.display

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils.np_utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing ICBHI_final_database from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mypath="/content/drive/MyDrive/Colab Notebooks/499/ICBHI_final_database/"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %% [markdown]
# Reading Demographic info file

# %%
path_demo ='/content/drive/MyDrive/Colab Notebooks/499/icbhi_other_files/demographic_info.txt'
col_names = ['patient_id', 'age', 'sex', 'adult_bmi', 'child_weight', 'child_height']

# Adult BMI (kg/m2)
# Child Weight (kg)
# Child Height (cm)

df_demo = pd.read_csv(path_demo, sep=" ", header=None, names=col_names)

df_demo.head(10)
# Out:
#    patient_id    age sex  adult_bmi  child_weight  child_height
# 0         101   3.00   F        NaN          19.0          99.0
# 1         102   0.75   F        NaN           9.8          73.0
# 2         103  70.00   F      33.00           NaN           NaN
# 3         104  70.00   F      28.47           NaN           NaN
# 4         105   7.00   F        NaN          32.0         135.0
# 5         106  73.00   F      21.00           NaN           NaN
# 6         107  75.00   F      33.70           NaN           NaN
# 7         108   3.00   M        NaN           NaN           NaN
# 8         109  84.00   F      33.53           NaN           NaN
# 9         110  75.00   M      25.21           NaN           NaN

# %% [markdown]
# Reading Patient diagnosis file

# %%
path_pat= \
'/content/drive/MyDrive/Colab Notebooks/499/icbhi_other_files/patient_diagnosis.csv'

df_diag = pd.read_csv(path_pat, header=None, names=['patient_id', 'diagnosis'])

df_diag.head(10)
# Out:
#    patient_id diagnosis
# 0         101      URTI
# 1         102   Healthy
# 2         103    Asthma
# 3         104      COPD
# 4         105      URTI
# 5         106      COPD
# 6         107      COPD
# 7         108      LRTI
# 8         109      COPD
# 9         110      COPD

# %% [markdown]
# Reading Filename format

# %%
path = \
'/content/drive/MyDrive/Colab Notebooks/499/icbhi_other_files/filename_format.txt.txt'

data = open(path, 'r').read()

data
# Out:
# 'Elements contained in the filenames:\n\nPatient number (101,102,...,226)\nRecording index\nChest location (Trachea (Tc), {Anterior (A), Posterior (P), Lateral (L)}{left (l), right (r)})\nAcquisition mode (sequential/single channel (sc), simultaneous/multichannel (mc))\nRecording equipment (AKG C417L Microphone, 3M Littmann Classic II SE Stethoscope, 3M Litmmann 3200 Electronic Stethoscope, WelchAllyn Meditron Master Elite Electronic Stethoscope)'

# %% [markdown]
# Reading an annotated txt file of its corresponding audio file

# %%
path_dis = \
'/content/drive/MyDrive/Colab Notebooks/499/ICBHI_final_database/101_1b1_Al_sc_Meditron.txt'

col_names = ['Beginning_of_respiratory_cycle', 'End_of_respiratory_cycle', 'Presence/absence_of_crackles', 'Presence/absence_of_wheezes']

# Respiratory cycle column values are in 'seconds'.
# Presence = 1
# Absence = 0

df_annot = pd.read_csv(path_dis, sep="\t", header=None, names=col_names)

df_annot.head(10)
# Out:
#    Beginning_of_respiratory_cycle  ...  Presence/absence_of_wheezes
# 0                           0.036  ...                            0
# 1                           0.579  ...                            0
# 2                           2.450  ...                            0
# 3                           3.893  ...                            0
# 4                           5.793  ...                            0
# 5                           7.521  ...                            0
# 6                           9.279  ...                            0
# 7                          11.150  ...                            0
# 8                          13.036  ...                            0
# 9                          14.721  ...                            0
#
# [10 rows x 4 columns]

# %%
path_spec = \
'/content/drive/MyDrive/Colab Notebooks/499/ICBHI_final_database/154_2b4_Al_mc_AKGC417L.txt'

col_names = ['Beginning_of_respiratory_cycle', 'End_of_respiratory_cycle', 'Presence/absence_of_crackles', 'Presence/absence_of_wheezes']

# Respiratory cycle column values are in 'seconds'.
# Presence = 1
# Absence = 0

df_annot = pd.read_csv(path_spec, sep="\t", header=None, names=col_names)

df_annot.head(20)
# Out:
#    Beginning_of_respiratory_cycle  ...  Presence/absence_of_wheezes
# 0                           1.330  ...                            0
# 1                           3.804  ...                            0
# 2                           6.396  ...                            0
# 3                           8.938  ...                            0
# 4                          11.580  ...                            0
# 5                          14.072  ...                            0
# 6                          17.049  ...                            0
#
# [7 rows x 4 columns]

# %% [markdown]
# We see that this recording contains 7 respiration cycles. We also see that crackles are present on 5 of the 7 cycles.

# %%
# Install the pysoundfile library
! pip install pysoundfile
# Out:
# Requirement already satisfied: pysoundfile in /usr/local/lib/python3.7/dist-packages (0.9.0.post1)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/dist-packages (from pysoundfile) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=0.6->pysoundfile) (2.20)

# %%
import soundfile as sf

# Define helper functions

# Load a .wav file. 
# These are 24 bit files. The PySoundFile library is able to read 24 bit files.
# https://pysoundfile.readthedocs.io/en/0.9.0/

def get_wav_info(wav_file):
    data, rate = sf.read(wav_file)
    return data, rate

# source: Andrew Ng Deep Learning Specialization, Course 5
def graph_spectrogram(wav_file):
    data, rate = get_wav_info(wav_file)
    nfft = 200 # Length of each window segment
    fs = 8000 # Sampling frequencies
    noverlap = 120 # Overlap between windows
    nchannels = data.ndim
    if nchannels == 1:
        pxx, freqs, bins, im = plt.specgram(data, nfft, fs, noverlap = noverlap)
    elif nchannels == 2:
        pxx, freqs, bins, im = plt.specgram(data[:,0], nfft, fs, noverlap = noverlap)
    return pxx

# %%
path = \
'/content/drive/MyDrive/Colab Notebooks/499/ICBHI_final_database/154_2b4_Al_mc_AKGC417L.wav'

# %%
x = graph_spectrogram(path)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:7592: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# Time is on the x axis and Frequencies are on the y axis. The intensity of the different colours shows the amount of energy i.e. how loud the sound is, at different frequencies, at different times.

# %% [markdown]
# **Part B: Plotting the MFCC**

# %%
max_pad_len = 862 # to make the length of all MFCC equal

def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it, and returns the MFCC
    of the audio"""
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=20) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccs

# %%
filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/499/icbhi_other_files/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
 features = []

 # Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# Finished feature extraction from  920  files

# %%
# plot an MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(features[7], x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
features = np.array(features) # convert to numpy array

# %%
# delete the very rare diseases
features1 = np.delete(features, np.where((labels == 'Asthma') | (labels == 'LRTI'))[0], axis=0) 

labels1 = np.delete(labels, np.where((labels == 'Asthma') | (labels == 'LRTI'))[0], axis=0)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels1, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Bronchiectasis' 'Bronchiolitis' 'COPD' 'Healthy' 'Pneumonia' 'URTI']
#  ['16' '13' '793' '35' '37' '23']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files (No Asthma or LRTI)')
plt.show()

# %%
# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(labels1)
oh_labels = to_categorical(i_labels)

# %%
# add channel dimension for CNN
features1 = np.reshape(features1, (*features1.shape,1))

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

#function
def train_test_rmse(x,y):
    x = Iris_data[x]
    y = Iris_data[y]
    x_train, x_test, y_train, y_test = train_test_split(x, y, features1, oh_labels, stratify=oh_labels, test_size = 0.2,random_state=42)
    linreg = LinearRegression()
    linreg.fit(x_train, y_train)
    y_pred = linreg.predict(x_test)
    print(accuracy_score(y_test, y_pred))  # or you can save it in variable and return it 
    return np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features1, oh_labels, stratify=oh_labels, test_size = 0.2,random_state=42)

# %% [markdown]
# **Part C: Creating CNN model**

# %%
num_rows = 40
num_columns = 862
num_channels = 1

num_labels = oh_labels.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 39, 861, 16)       80
#
#  max_pooling2d_20 (MaxPoolin  (None, 19, 430, 16)      0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 19, 430, 16)       0
#
#  conv2d_21 (Conv2D)          (None, 18, 429, 32)       2080
#
#  max_pooling2d_21 (MaxPoolin  (None, 9, 214, 32)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 9, 214, 32)        0
#
#  conv2d_22 (Conv2D)          (None, 8, 213, 64)        8256
#
#  max_pooling2d_22 (MaxPoolin  (None, 4, 106, 64)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 4, 106, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 3, 105, 128)       32896
#
#  max_pooling2d_23 (MaxPoolin  (None, 1, 52, 128)       0
#  g2D)
#
#  dropout_23 (Dropout)        (None, 1, 52, 128)        0
#
#  global_average_pooling2d_5   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 44,086
# Trainable params: 44,086
# Non-trainable params: 0
# _________________________________________________________________
# 6/6 [==============================] - 2s 171ms/step - loss: 9.6875 - accuracy: 0.0380
# Pre-training accuracy: 3.8043%

# %%
# train model
num_epochs = 250
num_batch_size = 128

callbacks = [
    ModelCheckpoint(
        filepath='mymodel2_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/250
# 6/6 [==============================] - ETA: 0s - loss: 5.8355 - accuracy: 0.6412
# Epoch 00001: val_accuracy improved from -inf to 0.43478, saving model to mymodel2_01.h5
# 6/6 [==============================] - 19s 3s/step - loss: 5.8355 - accuracy: 0.6412 - val_loss: 2.0654 - val_accuracy: 0.4348
# Epoch 2/250
# 6/6 [==============================] - ETA: 0s - loss: 3.9158 - accuracy: 0.7722
# Epoch 00002: val_accuracy improved from 0.43478 to 0.46739, saving model to mymodel2_02.h5
# 6/6 [==============================] - 16s 3s/step - loss: 3.9158 - accuracy: 0.7722 - val_loss: 1.7779 - val_accuracy: 0.4674
# Epoch 3/250
# 6/6 [==============================] - ETA: 0s - loss: 2.7578 - accuracy: 0.8513
# Epoch 00003: val_accuracy improved from 0.46739 to 0.50000, saving model to mymodel2_03.h5
# 6/6 [==============================] - 16s 3s/step - loss: 2.7578 - accuracy: 0.8513 - val_loss: 1.7243 - val_accuracy: 0.5000
# Epoch 4/250
# 6/6 [==============================] - ETA: 0s - loss: 2.0877 - accuracy: 0.8240
# Epoch 00004: val_accuracy improved from 0.50000 to 0.81522, saving model to mymodel2_04.h5
# 6/6 [==============================] - 16s 3s/step - loss: 2.0877 - accuracy: 0.8240 - val_loss: 1.1605 - val_accuracy: 0.8152
# Epoch 5/250
# 6/6 [==============================] - ETA: 0s - loss: 1.2356 - accuracy: 0.8513
# Epoch 00005: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 1.2356 - accuracy: 0.8513 - val_loss: 1.3461 - val_accuracy: 0.3804
# Epoch 6/250
# 6/6 [==============================] - ETA: 0s - loss: 0.8281 - accuracy: 0.8608
# Epoch 00006: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.8281 - accuracy: 0.8608 - val_loss: 1.4940 - val_accuracy: 0.2772
# Epoch 7/250
# 6/6 [==============================] - ETA: 0s - loss: 0.6646 - accuracy: 0.8117
# Epoch 00007: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.6646 - accuracy: 0.8117 - val_loss: 1.3898 - val_accuracy: 0.2826
# Epoch 8/250
# 6/6 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.8608
# Epoch 00008: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.6164 - accuracy: 0.8608 - val_loss: 0.9534 - val_accuracy: 0.7391
# Epoch 9/250
# 6/6 [==============================] - ETA: 0s - loss: 0.6078 - accuracy: 0.8336
# Epoch 00009: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.6078 - accuracy: 0.8336 - val_loss: 0.9760 - val_accuracy: 0.7174
# Epoch 10/250
# 6/6 [==============================] - ETA: 0s - loss: 0.5500 - accuracy: 0.8568
# Epoch 00010: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.5500 - accuracy: 0.8568 - val_loss: 1.0768 - val_accuracy: 0.6359
# Epoch 11/250
# 6/6 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.8431
# Epoch 00011: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.5110 - accuracy: 0.8431 - val_loss: 0.9330 - val_accuracy: 0.7391
# Epoch 12/250
# 6/6 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.8554
# Epoch 00012: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.5022 - accuracy: 0.8554 - val_loss: 0.8398 - val_accuracy: 0.7663
# Epoch 13/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4954 - accuracy: 0.8540
# Epoch 00013: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4954 - accuracy: 0.8540 - val_loss: 0.9294 - val_accuracy: 0.7337
# Epoch 14/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.8458
# Epoch 00014: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 15s 3s/step - loss: 0.4854 - accuracy: 0.8458 - val_loss: 0.8402 - val_accuracy: 0.7500
# Epoch 15/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.8513
# Epoch 00015: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4862 - accuracy: 0.8513 - val_loss: 0.8774 - val_accuracy: 0.7554
# Epoch 16/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8595
# Epoch 00016: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4378 - accuracy: 0.8595 - val_loss: 0.8329 - val_accuracy: 0.7609
# Epoch 17/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.8608
# Epoch 00017: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4605 - accuracy: 0.8608 - val_loss: 0.8061 - val_accuracy: 0.7772
# Epoch 18/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4469 - accuracy: 0.8581
# Epoch 00018: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4469 - accuracy: 0.8581 - val_loss: 0.8180 - val_accuracy: 0.7663
# Epoch 19/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8608
# Epoch 00019: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4464 - accuracy: 0.8608 - val_loss: 0.7904 - val_accuracy: 0.7772
# Epoch 20/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4328 - accuracy: 0.8677
# Epoch 00020: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4328 - accuracy: 0.8677 - val_loss: 0.7722 - val_accuracy: 0.7880
# Epoch 21/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8486
# Epoch 00021: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4334 - accuracy: 0.8486 - val_loss: 0.7780 - val_accuracy: 0.7772
# Epoch 22/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8649
# Epoch 00022: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4378 - accuracy: 0.8649 - val_loss: 0.7628 - val_accuracy: 0.7772
# Epoch 23/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.8649
# Epoch 00023: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4113 - accuracy: 0.8649 - val_loss: 0.7481 - val_accuracy: 0.7826
# Epoch 24/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.8677
# Epoch 00024: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4333 - accuracy: 0.8677 - val_loss: 0.7373 - val_accuracy: 0.7935
# Epoch 25/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.8663
# Epoch 00025: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4258 - accuracy: 0.8663 - val_loss: 0.7844 - val_accuracy: 0.7717
# Epoch 26/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8554
# Epoch 00026: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4215 - accuracy: 0.8554 - val_loss: 0.7288 - val_accuracy: 0.7880
# Epoch 27/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8595
# Epoch 00027: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4032 - accuracy: 0.8595 - val_loss: 0.7481 - val_accuracy: 0.7772
# Epoch 28/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8772
# Epoch 00028: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3925 - accuracy: 0.8772 - val_loss: 0.7127 - val_accuracy: 0.7772
# Epoch 29/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4089 - accuracy: 0.8704
# Epoch 00029: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4089 - accuracy: 0.8704 - val_loss: 0.7504 - val_accuracy: 0.7772
# Epoch 30/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4110 - accuracy: 0.8636
# Epoch 00030: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4110 - accuracy: 0.8636 - val_loss: 0.6941 - val_accuracy: 0.7880
# Epoch 31/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8745
# Epoch 00031: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3748 - accuracy: 0.8745 - val_loss: 0.7408 - val_accuracy: 0.7717
# Epoch 32/250
# 6/6 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8581
# Epoch 00032: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.4045 - accuracy: 0.8581 - val_loss: 0.7156 - val_accuracy: 0.7772
# Epoch 33/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8704
# Epoch 00033: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3743 - accuracy: 0.8704 - val_loss: 0.6670 - val_accuracy: 0.7989
# Epoch 34/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8731
# Epoch 00034: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3934 - accuracy: 0.8731 - val_loss: 0.6743 - val_accuracy: 0.8043
# Epoch 35/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.8731
# Epoch 00035: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3839 - accuracy: 0.8731 - val_loss: 0.6932 - val_accuracy: 0.7717
# Epoch 36/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3797 - accuracy: 0.8759
# Epoch 00036: val_accuracy did not improve from 0.81522
# 6/6 [==============================] - 16s 3s/step - loss: 0.3797 - accuracy: 0.8759 - val_loss: 0.6538 - val_accuracy: 0.7826
# Epoch 37/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8704
# Epoch 00037: val_accuracy improved from 0.81522 to 0.82065, saving model to mymodel2_37.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.3746 - accuracy: 0.8704 - val_loss: 0.6031 - val_accuracy: 0.8207
# Epoch 38/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8759
# Epoch 00038: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3680 - accuracy: 0.8759 - val_loss: 0.6199 - val_accuracy: 0.7989
# Epoch 39/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3685 - accuracy: 0.8745
# Epoch 00039: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 19s 3s/step - loss: 0.3685 - accuracy: 0.8745 - val_loss: 0.7085 - val_accuracy: 0.7554
# Epoch 40/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3877 - accuracy: 0.8731
# Epoch 00040: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3877 - accuracy: 0.8731 - val_loss: 0.5209 - val_accuracy: 0.8152
# Epoch 41/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8677
# Epoch 00041: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3773 - accuracy: 0.8677 - val_loss: 0.7162 - val_accuracy: 0.7554
# Epoch 42/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3843 - accuracy: 0.8663
# Epoch 00042: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3843 - accuracy: 0.8663 - val_loss: 0.5932 - val_accuracy: 0.7989
# Epoch 43/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8690
# Epoch 00043: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3826 - accuracy: 0.8690 - val_loss: 0.5259 - val_accuracy: 0.8152
# Epoch 44/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3799 - accuracy: 0.8704
# Epoch 00044: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3799 - accuracy: 0.8704 - val_loss: 0.6537 - val_accuracy: 0.7772
# Epoch 45/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8772
# Epoch 00045: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3478 - accuracy: 0.8772 - val_loss: 0.5638 - val_accuracy: 0.8207
# Epoch 46/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.8772
# Epoch 00046: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3385 - accuracy: 0.8772 - val_loss: 0.5582 - val_accuracy: 0.8098
# Epoch 47/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.8840
# Epoch 00047: val_accuracy did not improve from 0.82065
# 6/6 [==============================] - 16s 3s/step - loss: 0.3317 - accuracy: 0.8840 - val_loss: 0.5716 - val_accuracy: 0.8207
# Epoch 48/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8868
# Epoch 00048: val_accuracy improved from 0.82065 to 0.84239, saving model to mymodel2_48.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.3293 - accuracy: 0.8868 - val_loss: 0.5341 - val_accuracy: 0.8424
# Epoch 49/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8799
# Epoch 00049: val_accuracy did not improve from 0.84239
# 6/6 [==============================] - 16s 3s/step - loss: 0.3327 - accuracy: 0.8799 - val_loss: 0.5264 - val_accuracy: 0.8315
# Epoch 50/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.8840
# Epoch 00050: val_accuracy improved from 0.84239 to 0.84783, saving model to mymodel2_50.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.3160 - accuracy: 0.8840 - val_loss: 0.5178 - val_accuracy: 0.8478
# Epoch 51/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.8909
# Epoch 00051: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.3191 - accuracy: 0.8909 - val_loss: 0.5339 - val_accuracy: 0.8152
# Epoch 52/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8786
# Epoch 00052: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.3253 - accuracy: 0.8786 - val_loss: 0.4731 - val_accuracy: 0.8370
# Epoch 53/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.8895
# Epoch 00053: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.3006 - accuracy: 0.8895 - val_loss: 0.4950 - val_accuracy: 0.8478
# Epoch 54/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.8909
# Epoch 00054: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.3098 - accuracy: 0.8909 - val_loss: 0.5165 - val_accuracy: 0.8315
# Epoch 55/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.8895
# Epoch 00055: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.3073 - accuracy: 0.8895 - val_loss: 0.4528 - val_accuracy: 0.8424
# Epoch 56/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8840
# Epoch 00056: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.2935 - accuracy: 0.8840 - val_loss: 0.4666 - val_accuracy: 0.8478
# Epoch 57/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.8909
# Epoch 00057: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.2951 - accuracy: 0.8909 - val_loss: 0.4691 - val_accuracy: 0.8424
# Epoch 58/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.8840
# Epoch 00058: val_accuracy did not improve from 0.84783
# 6/6 [==============================] - 16s 3s/step - loss: 0.2958 - accuracy: 0.8840 - val_loss: 0.4646 - val_accuracy: 0.8424
# Epoch 59/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9004
# Epoch 00059: val_accuracy improved from 0.84783 to 0.85326, saving model to mymodel2_59.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.2887 - accuracy: 0.9004 - val_loss: 0.4305 - val_accuracy: 0.8533
# Epoch 60/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.8895
# Epoch 00060: val_accuracy did not improve from 0.85326
# 6/6 [==============================] - 16s 3s/step - loss: 0.2893 - accuracy: 0.8895 - val_loss: 0.4948 - val_accuracy: 0.8424
# Epoch 61/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8909
# Epoch 00061: val_accuracy did not improve from 0.85326
# 6/6 [==============================] - 16s 3s/step - loss: 0.3071 - accuracy: 0.8909 - val_loss: 0.4223 - val_accuracy: 0.8478
# Epoch 62/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.8854
# Epoch 00062: val_accuracy did not improve from 0.85326
# 6/6 [==============================] - 16s 3s/step - loss: 0.3026 - accuracy: 0.8854 - val_loss: 0.4562 - val_accuracy: 0.8478
# Epoch 63/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8813
# Epoch 00063: val_accuracy improved from 0.85326 to 0.85870, saving model to mymodel2_63.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.3331 - accuracy: 0.8813 - val_loss: 0.3944 - val_accuracy: 0.8587
# Epoch 64/250
# 6/6 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8854
# Epoch 00064: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.3128 - accuracy: 0.8854 - val_loss: 0.4441 - val_accuracy: 0.8533
# Epoch 65/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8895
# Epoch 00065: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 17s 3s/step - loss: 0.2858 - accuracy: 0.8895 - val_loss: 0.4705 - val_accuracy: 0.8533
# Epoch 66/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.8922
# Epoch 00066: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2725 - accuracy: 0.8922 - val_loss: 0.4035 - val_accuracy: 0.8478
# Epoch 67/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.8909
# Epoch 00067: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2860 - accuracy: 0.8909 - val_loss: 0.4294 - val_accuracy: 0.8587
# Epoch 68/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.8827
# Epoch 00068: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2775 - accuracy: 0.8827 - val_loss: 0.4174 - val_accuracy: 0.8587
# Epoch 69/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.9018
# Epoch 00069: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2696 - accuracy: 0.9018 - val_loss: 0.4365 - val_accuracy: 0.8533
# Epoch 70/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.8868
# Epoch 00070: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2917 - accuracy: 0.8868 - val_loss: 0.4229 - val_accuracy: 0.8587
# Epoch 71/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.9045
# Epoch 00071: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2630 - accuracy: 0.9045 - val_loss: 0.3901 - val_accuracy: 0.8587
# Epoch 72/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9018
# Epoch 00072: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2558 - accuracy: 0.9018 - val_loss: 0.3990 - val_accuracy: 0.8533
# Epoch 73/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.8990
# Epoch 00073: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2487 - accuracy: 0.8990 - val_loss: 0.3868 - val_accuracy: 0.8587
# Epoch 74/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.8950
# Epoch 00074: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2537 - accuracy: 0.8950 - val_loss: 0.4209 - val_accuracy: 0.8587
# Epoch 75/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9031
# Epoch 00075: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2387 - accuracy: 0.9031 - val_loss: 0.3708 - val_accuracy: 0.8587
# Epoch 76/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.9059
# Epoch 00076: val_accuracy did not improve from 0.85870
# 6/6 [==============================] - 16s 3s/step - loss: 0.2532 - accuracy: 0.9059 - val_loss: 0.3689 - val_accuracy: 0.8587
# Epoch 77/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2461 - accuracy: 0.9113
# Epoch 00077: val_accuracy improved from 0.85870 to 0.86413, saving model to mymodel2_77.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.2461 - accuracy: 0.9113 - val_loss: 0.3757 - val_accuracy: 0.8641
# Epoch 78/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.9222
# Epoch 00078: val_accuracy did not improve from 0.86413
# 6/6 [==============================] - 16s 3s/step - loss: 0.2229 - accuracy: 0.9222 - val_loss: 0.3684 - val_accuracy: 0.8587
# Epoch 79/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9086
# Epoch 00079: val_accuracy did not improve from 0.86413
# 6/6 [==============================] - 16s 3s/step - loss: 0.2354 - accuracy: 0.9086 - val_loss: 0.3595 - val_accuracy: 0.8641
# Epoch 80/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9154
# Epoch 00080: val_accuracy improved from 0.86413 to 0.87500, saving model to mymodel2_80.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.2499 - accuracy: 0.9154 - val_loss: 0.3871 - val_accuracy: 0.8750
# Epoch 81/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.9113
# Epoch 00081: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2467 - accuracy: 0.9113 - val_loss: 0.4067 - val_accuracy: 0.8696
# Epoch 82/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9059
# Epoch 00082: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2428 - accuracy: 0.9059 - val_loss: 0.3724 - val_accuracy: 0.8587
# Epoch 83/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9127
# Epoch 00083: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2540 - accuracy: 0.9127 - val_loss: 0.3847 - val_accuracy: 0.8750
# Epoch 84/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9113
# Epoch 00084: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2337 - accuracy: 0.9113 - val_loss: 0.3826 - val_accuracy: 0.8696
# Epoch 85/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2370 - accuracy: 0.9100
# Epoch 00085: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2370 - accuracy: 0.9100 - val_loss: 0.3571 - val_accuracy: 0.8533
# Epoch 86/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9127
# Epoch 00086: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2291 - accuracy: 0.9127 - val_loss: 0.3459 - val_accuracy: 0.8533
# Epoch 87/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9100
# Epoch 00087: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2328 - accuracy: 0.9100 - val_loss: 0.3854 - val_accuracy: 0.8696
# Epoch 88/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9154
# Epoch 00088: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2388 - accuracy: 0.9154 - val_loss: 0.3651 - val_accuracy: 0.8750
# Epoch 89/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9127
# Epoch 00089: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2269 - accuracy: 0.9127 - val_loss: 0.3537 - val_accuracy: 0.8641
# Epoch 90/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9127
# Epoch 00090: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2477 - accuracy: 0.9127 - val_loss: 0.3725 - val_accuracy: 0.8587
# Epoch 91/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9113
# Epoch 00091: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2390 - accuracy: 0.9113 - val_loss: 0.3564 - val_accuracy: 0.8750
# Epoch 92/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9168
# Epoch 00092: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2494 - accuracy: 0.9168 - val_loss: 0.3510 - val_accuracy: 0.8641
# Epoch 93/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9031
# Epoch 00093: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2474 - accuracy: 0.9031 - val_loss: 0.3711 - val_accuracy: 0.8641
# Epoch 94/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9086
# Epoch 00094: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2190 - accuracy: 0.9086 - val_loss: 0.3390 - val_accuracy: 0.8641
# Epoch 95/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9086
# Epoch 00095: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2153 - accuracy: 0.9086 - val_loss: 0.3475 - val_accuracy: 0.8587
# Epoch 96/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9031
# Epoch 00096: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2173 - accuracy: 0.9031 - val_loss: 0.3553 - val_accuracy: 0.8641
# Epoch 97/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9222
# Epoch 00097: val_accuracy did not improve from 0.87500
# 6/6 [==============================] - 16s 3s/step - loss: 0.2159 - accuracy: 0.9222 - val_loss: 0.3598 - val_accuracy: 0.8641
# Epoch 98/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9209
# Epoch 00098: val_accuracy improved from 0.87500 to 0.88587, saving model to mymodel2_98.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.2187 - accuracy: 0.9209 - val_loss: 0.3409 - val_accuracy: 0.8859
# Epoch 99/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9127
# Epoch 00099: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2172 - accuracy: 0.9127 - val_loss: 0.3443 - val_accuracy: 0.8750
# Epoch 100/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9209
# Epoch 00100: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2188 - accuracy: 0.9209 - val_loss: 0.3764 - val_accuracy: 0.8587
# Epoch 101/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9168
# Epoch 00101: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2117 - accuracy: 0.9168 - val_loss: 0.3308 - val_accuracy: 0.8750
# Epoch 102/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9195
# Epoch 00102: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2016 - accuracy: 0.9195 - val_loss: 0.3374 - val_accuracy: 0.8696
# Epoch 103/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9291
# Epoch 00103: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1907 - accuracy: 0.9291 - val_loss: 0.3457 - val_accuracy: 0.8696
# Epoch 104/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.9250
# Epoch 00104: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2046 - accuracy: 0.9250 - val_loss: 0.3703 - val_accuracy: 0.8641
# Epoch 105/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9250
# Epoch 00105: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2066 - accuracy: 0.9250 - val_loss: 0.3480 - val_accuracy: 0.8696
# Epoch 106/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9359
# Epoch 00106: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1872 - accuracy: 0.9359 - val_loss: 0.3773 - val_accuracy: 0.8587
# Epoch 107/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9141
# Epoch 00107: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.2153 - accuracy: 0.9141 - val_loss: 0.3508 - val_accuracy: 0.8750
# Epoch 108/250
# 6/6 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9072
# Epoch 00108: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 18s 3s/step - loss: 0.2036 - accuracy: 0.9072 - val_loss: 0.3579 - val_accuracy: 0.8641
# Epoch 109/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9250
# Epoch 00109: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1851 - accuracy: 0.9250 - val_loss: 0.3423 - val_accuracy: 0.8696
# Epoch 110/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9332
# Epoch 00110: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1672 - accuracy: 0.9332 - val_loss: 0.3455 - val_accuracy: 0.8696
# Epoch 111/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9345
# Epoch 00111: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1742 - accuracy: 0.9345 - val_loss: 0.3513 - val_accuracy: 0.8587
# Epoch 112/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9318
# Epoch 00112: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1777 - accuracy: 0.9318 - val_loss: 0.3501 - val_accuracy: 0.8696
# Epoch 113/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9304
# Epoch 00113: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1777 - accuracy: 0.9304 - val_loss: 0.3471 - val_accuracy: 0.8641
# Epoch 114/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9277
# Epoch 00114: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1701 - accuracy: 0.9277 - val_loss: 0.3573 - val_accuracy: 0.8804
# Epoch 115/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9372
# Epoch 00115: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1622 - accuracy: 0.9372 - val_loss: 0.3640 - val_accuracy: 0.8641
# Epoch 116/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9372
# Epoch 00116: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1610 - accuracy: 0.9372 - val_loss: 0.3573 - val_accuracy: 0.8696
# Epoch 117/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9372
# Epoch 00117: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1551 - accuracy: 0.9372 - val_loss: 0.3645 - val_accuracy: 0.8859
# Epoch 118/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9454
# Epoch 00118: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1614 - accuracy: 0.9454 - val_loss: 0.3772 - val_accuracy: 0.8804
# Epoch 119/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9372
# Epoch 00119: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1563 - accuracy: 0.9372 - val_loss: 0.3652 - val_accuracy: 0.8859
# Epoch 120/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9413
# Epoch 00120: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1565 - accuracy: 0.9413 - val_loss: 0.3786 - val_accuracy: 0.8804
# Epoch 121/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9427
# Epoch 00121: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1558 - accuracy: 0.9427 - val_loss: 0.4259 - val_accuracy: 0.8804
# Epoch 122/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9318
# Epoch 00122: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1775 - accuracy: 0.9318 - val_loss: 0.4031 - val_accuracy: 0.8696
# Epoch 123/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9291
# Epoch 00123: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1795 - accuracy: 0.9291 - val_loss: 0.3608 - val_accuracy: 0.8750
# Epoch 124/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9250
# Epoch 00124: val_accuracy did not improve from 0.88587
# 6/6 [==============================] - 16s 3s/step - loss: 0.1543 - accuracy: 0.9250 - val_loss: 0.3787 - val_accuracy: 0.8804
# Epoch 125/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9441
# Epoch 00125: val_accuracy improved from 0.88587 to 0.89130, saving model to mymodel2_125.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.1489 - accuracy: 0.9441 - val_loss: 0.3626 - val_accuracy: 0.8913
# Epoch 126/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9332
# Epoch 00126: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1634 - accuracy: 0.9332 - val_loss: 0.3785 - val_accuracy: 0.8804
# Epoch 127/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9359
# Epoch 00127: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1592 - accuracy: 0.9359 - val_loss: 0.3784 - val_accuracy: 0.8804
# Epoch 128/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9332
# Epoch 00128: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1731 - accuracy: 0.9332 - val_loss: 0.3717 - val_accuracy: 0.8859
# Epoch 129/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9454
# Epoch 00129: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1458 - accuracy: 0.9454 - val_loss: 0.3818 - val_accuracy: 0.8859
# Epoch 130/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9386
# Epoch 00130: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1552 - accuracy: 0.9386 - val_loss: 0.3826 - val_accuracy: 0.8859
# Epoch 131/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9509
# Epoch 00131: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1434 - accuracy: 0.9509 - val_loss: 0.3618 - val_accuracy: 0.8913
# Epoch 132/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9495
# Epoch 00132: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1287 - accuracy: 0.9495 - val_loss: 0.3931 - val_accuracy: 0.8750
# Epoch 133/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9563
# Epoch 00133: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1202 - accuracy: 0.9563 - val_loss: 0.4086 - val_accuracy: 0.8913
# Epoch 134/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9550
# Epoch 00134: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1298 - accuracy: 0.9550 - val_loss: 0.3771 - val_accuracy: 0.8913
# Epoch 135/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9577
# Epoch 00135: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1215 - accuracy: 0.9577 - val_loss: 0.3870 - val_accuracy: 0.8750
# Epoch 136/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9604
# Epoch 00136: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1128 - accuracy: 0.9604 - val_loss: 0.4346 - val_accuracy: 0.8750
# Epoch 137/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9400
# Epoch 00137: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1428 - accuracy: 0.9400 - val_loss: 0.4008 - val_accuracy: 0.8859
# Epoch 138/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9523
# Epoch 00138: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1292 - accuracy: 0.9523 - val_loss: 0.4115 - val_accuracy: 0.8804
# Epoch 139/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9468
# Epoch 00139: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1249 - accuracy: 0.9468 - val_loss: 0.4033 - val_accuracy: 0.8913
# Epoch 140/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9454
# Epoch 00140: val_accuracy did not improve from 0.89130
# 6/6 [==============================] - 16s 3s/step - loss: 0.1261 - accuracy: 0.9454 - val_loss: 0.4026 - val_accuracy: 0.8859
# Epoch 141/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9550
# Epoch 00141: val_accuracy improved from 0.89130 to 0.89674, saving model to mymodel2_141.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.1149 - accuracy: 0.9550 - val_loss: 0.3772 - val_accuracy: 0.8967
# Epoch 142/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9536
# Epoch 00142: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1167 - accuracy: 0.9536 - val_loss: 0.4236 - val_accuracy: 0.8859
# Epoch 143/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9604
# Epoch 00143: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1072 - accuracy: 0.9604 - val_loss: 0.4280 - val_accuracy: 0.8804
# Epoch 144/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9618
# Epoch 00144: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1056 - accuracy: 0.9618 - val_loss: 0.3897 - val_accuracy: 0.8967
# Epoch 145/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9686
# Epoch 00145: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1079 - accuracy: 0.9686 - val_loss: 0.3913 - val_accuracy: 0.8913
# Epoch 146/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9509
# Epoch 00146: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1210 - accuracy: 0.9509 - val_loss: 0.4279 - val_accuracy: 0.8859
# Epoch 147/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9618
# Epoch 00147: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1033 - accuracy: 0.9618 - val_loss: 0.4161 - val_accuracy: 0.8913
# Epoch 148/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9550
# Epoch 00148: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1168 - accuracy: 0.9550 - val_loss: 0.4569 - val_accuracy: 0.8804
# Epoch 149/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9454
# Epoch 00149: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1224 - accuracy: 0.9454 - val_loss: 0.4566 - val_accuracy: 0.8804
# Epoch 150/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9604
# Epoch 00150: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1133 - accuracy: 0.9604 - val_loss: 0.4253 - val_accuracy: 0.8913
# Epoch 151/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9536
# Epoch 00151: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1114 - accuracy: 0.9536 - val_loss: 0.4457 - val_accuracy: 0.8750
# Epoch 152/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9563
# Epoch 00152: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1014 - accuracy: 0.9563 - val_loss: 0.4106 - val_accuracy: 0.8859
# Epoch 153/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9550
# Epoch 00153: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1100 - accuracy: 0.9550 - val_loss: 0.4174 - val_accuracy: 0.8750
# Epoch 154/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9591
# Epoch 00154: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1019 - accuracy: 0.9591 - val_loss: 0.4259 - val_accuracy: 0.8859
# Epoch 155/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9632
# Epoch 00155: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0982 - accuracy: 0.9632 - val_loss: 0.4491 - val_accuracy: 0.8804
# Epoch 156/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9659
# Epoch 00156: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0993 - accuracy: 0.9659 - val_loss: 0.4576 - val_accuracy: 0.8967
# Epoch 157/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9482
# Epoch 00157: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1188 - accuracy: 0.9482 - val_loss: 0.4490 - val_accuracy: 0.8859
# Epoch 158/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9563
# Epoch 00158: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1169 - accuracy: 0.9563 - val_loss: 0.4548 - val_accuracy: 0.8804
# Epoch 159/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9604
# Epoch 00159: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1094 - accuracy: 0.9604 - val_loss: 0.4246 - val_accuracy: 0.8859
# Epoch 160/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9659
# Epoch 00160: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0975 - accuracy: 0.9659 - val_loss: 0.4473 - val_accuracy: 0.8750
# Epoch 161/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9686
# Epoch 00161: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0892 - accuracy: 0.9686 - val_loss: 0.4247 - val_accuracy: 0.8804
# Epoch 162/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9659
# Epoch 00162: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0915 - accuracy: 0.9659 - val_loss: 0.4161 - val_accuracy: 0.8913
# Epoch 163/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9686
# Epoch 00163: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0878 - accuracy: 0.9686 - val_loss: 0.4074 - val_accuracy: 0.8859
# Epoch 164/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9577
# Epoch 00164: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0883 - accuracy: 0.9577 - val_loss: 0.4667 - val_accuracy: 0.8804
# Epoch 165/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9673
# Epoch 00165: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0885 - accuracy: 0.9673 - val_loss: 0.4490 - val_accuracy: 0.8859
# Epoch 166/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9741
# Epoch 00166: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0907 - accuracy: 0.9741 - val_loss: 0.4393 - val_accuracy: 0.8913
# Epoch 167/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9714
# Epoch 00167: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0878 - accuracy: 0.9714 - val_loss: 0.4330 - val_accuracy: 0.8913
# Epoch 168/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9714
# Epoch 00168: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0943 - accuracy: 0.9714 - val_loss: 0.4759 - val_accuracy: 0.8804
# Epoch 169/250
# 6/6 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9577
# Epoch 00169: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.1004 - accuracy: 0.9577 - val_loss: 0.4922 - val_accuracy: 0.8750
# Epoch 170/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9604
# Epoch 00170: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0994 - accuracy: 0.9604 - val_loss: 0.4645 - val_accuracy: 0.8859
# Epoch 171/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9563
# Epoch 00171: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0938 - accuracy: 0.9563 - val_loss: 0.4938 - val_accuracy: 0.8804
# Epoch 172/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9659
# Epoch 00172: val_accuracy did not improve from 0.89674
# ...
# Epoch 194/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9700
# Epoch 00194: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0668 - accuracy: 0.9700 - val_loss: 0.5368 - val_accuracy: 0.8804
# Epoch 195/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9850
# Epoch 00195: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0500 - accuracy: 0.9850 - val_loss: 0.5228 - val_accuracy: 0.8967
# Epoch 196/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9768
# Epoch 00196: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0633 - accuracy: 0.9768 - val_loss: 0.6654 - val_accuracy: 0.8641
# Epoch 197/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9809
# Epoch 00197: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0548 - accuracy: 0.9809 - val_loss: 0.5465 - val_accuracy: 0.8804
# Epoch 198/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9823
# Epoch 00198: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0658 - accuracy: 0.9823 - val_loss: 0.5561 - val_accuracy: 0.8859
# Epoch 199/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9795
# Epoch 00199: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0661 - accuracy: 0.9795 - val_loss: 0.5479 - val_accuracy: 0.8750
# Epoch 200/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9795
# Epoch 00200: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0559 - accuracy: 0.9795 - val_loss: 0.5000 - val_accuracy: 0.8967
# Epoch 201/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9809
# Epoch 00201: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0530 - accuracy: 0.9809 - val_loss: 0.5324 - val_accuracy: 0.8967
# Epoch 202/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9823
# Epoch 00202: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0523 - accuracy: 0.9823 - val_loss: 0.5624 - val_accuracy: 0.8859
# Epoch 203/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9795
# Epoch 00203: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0517 - accuracy: 0.9795 - val_loss: 0.5214 - val_accuracy: 0.8913
# Epoch 204/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9836
# Epoch 00204: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0463 - accuracy: 0.9836 - val_loss: 0.5746 - val_accuracy: 0.8859
# Epoch 205/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9891
# Epoch 00205: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0437 - accuracy: 0.9891 - val_loss: 0.5279 - val_accuracy: 0.8967
# Epoch 206/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9768
# Epoch 00206: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0579 - accuracy: 0.9768 - val_loss: 0.5579 - val_accuracy: 0.8696
# Epoch 207/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9741
# Epoch 00207: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0634 - accuracy: 0.9741 - val_loss: 0.6082 - val_accuracy: 0.8859
# Epoch 208/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9795
# Epoch 00208: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0539 - accuracy: 0.9795 - val_loss: 0.5947 - val_accuracy: 0.8967
# Epoch 209/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9754
# Epoch 00209: val_accuracy did not improve from 0.89674
# 6/6 [==============================] - 16s 3s/step - loss: 0.0698 - accuracy: 0.9754 - val_loss: 0.5911 - val_accuracy: 0.8696
# Epoch 210/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9795
# Epoch 00210: val_accuracy improved from 0.89674 to 0.90217, saving model to mymodel2_210.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.0557 - accuracy: 0.9795 - val_loss: 0.5716 - val_accuracy: 0.9022
# Epoch 211/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9809
# Epoch 00211: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0547 - accuracy: 0.9809 - val_loss: 0.6307 - val_accuracy: 0.8913
# Epoch 212/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9809
# Epoch 00212: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0536 - accuracy: 0.9809 - val_loss: 0.6177 - val_accuracy: 0.8696
# Epoch 213/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9686
# Epoch 00213: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0711 - accuracy: 0.9686 - val_loss: 0.5526 - val_accuracy: 0.8913
# Epoch 214/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9864
# Epoch 00214: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0408 - accuracy: 0.9864 - val_loss: 0.4965 - val_accuracy: 0.8967
# Epoch 215/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9850
# Epoch 00215: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0428 - accuracy: 0.9850 - val_loss: 0.5450 - val_accuracy: 0.8859
# Epoch 216/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9891
# Epoch 00216: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0393 - accuracy: 0.9891 - val_loss: 0.5930 - val_accuracy: 0.8859
# Epoch 217/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9877
# Epoch 00217: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0422 - accuracy: 0.9877 - val_loss: 0.4948 - val_accuracy: 0.9022
# Epoch 218/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9823
# Epoch 00218: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0480 - accuracy: 0.9823 - val_loss: 0.5182 - val_accuracy: 0.8859
# Epoch 219/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9877
# Epoch 00219: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0460 - accuracy: 0.9877 - val_loss: 0.5950 - val_accuracy: 0.8967
# Epoch 220/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9864
# Epoch 00220: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0434 - accuracy: 0.9864 - val_loss: 0.5652 - val_accuracy: 0.8967
# Epoch 221/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9877
# Epoch 00221: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0407 - accuracy: 0.9877 - val_loss: 0.5573 - val_accuracy: 0.9022
# Epoch 222/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9836
# Epoch 00222: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0465 - accuracy: 0.9836 - val_loss: 0.5751 - val_accuracy: 0.8967
# Epoch 223/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9836
# Epoch 00223: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0386 - accuracy: 0.9836 - val_loss: 0.5388 - val_accuracy: 0.8913
# Epoch 224/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9864
# Epoch 00224: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0447 - accuracy: 0.9864 - val_loss: 0.5799 - val_accuracy: 0.8913
# Epoch 225/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9905
# Epoch 00225: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0361 - accuracy: 0.9905 - val_loss: 0.6010 - val_accuracy: 0.8913
# Epoch 226/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9891
# Epoch 00226: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0415 - accuracy: 0.9891 - val_loss: 0.5867 - val_accuracy: 0.8804
# Epoch 227/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9850
# Epoch 00227: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0504 - accuracy: 0.9850 - val_loss: 0.5508 - val_accuracy: 0.8967
# Epoch 228/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9823
# Epoch 00228: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0446 - accuracy: 0.9823 - val_loss: 0.6058 - val_accuracy: 0.8967
# Epoch 229/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9809
# Epoch 00229: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0474 - accuracy: 0.9809 - val_loss: 0.5440 - val_accuracy: 0.9022
# Epoch 230/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9905
# Epoch 00230: val_accuracy did not improve from 0.90217
# 6/6 [==============================] - 16s 3s/step - loss: 0.0365 - accuracy: 0.9905 - val_loss: 0.6255 - val_accuracy: 0.8967
# Epoch 231/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9864
# Epoch 00231: val_accuracy improved from 0.90217 to 0.90761, saving model to mymodel2_231.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.0396 - accuracy: 0.9864 - val_loss: 0.5928 - val_accuracy: 0.9076
# Epoch 232/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9864
# Epoch 00232: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0398 - accuracy: 0.9864 - val_loss: 0.6071 - val_accuracy: 0.8967
# Epoch 233/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9932
# Epoch 00233: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0331 - accuracy: 0.9932 - val_loss: 0.6751 - val_accuracy: 0.8913
# Epoch 234/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9864
# Epoch 00234: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0375 - accuracy: 0.9864 - val_loss: 0.6326 - val_accuracy: 0.9022
# Epoch 235/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9809
# Epoch 00235: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 18s 3s/step - loss: 0.0564 - accuracy: 0.9809 - val_loss: 0.6146 - val_accuracy: 0.8750
# Epoch 236/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9741
# Epoch 00236: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0590 - accuracy: 0.9741 - val_loss: 0.6383 - val_accuracy: 0.9022
# Epoch 237/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9795
# Epoch 00237: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0518 - accuracy: 0.9795 - val_loss: 0.6120 - val_accuracy: 0.8913
# Epoch 238/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9795
# Epoch 00238: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0507 - accuracy: 0.9795 - val_loss: 0.5868 - val_accuracy: 0.9022
# Epoch 239/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9809
# Epoch 00239: val_accuracy did not improve from 0.90761
# 6/6 [==============================] - 16s 3s/step - loss: 0.0462 - accuracy: 0.9809 - val_loss: 0.6037 - val_accuracy: 0.8859
# Epoch 240/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9714
# Epoch 00240: val_accuracy improved from 0.90761 to 0.91304, saving model to mymodel2_240.h5
# 6/6 [==============================] - 16s 3s/step - loss: 0.0622 - accuracy: 0.9714 - val_loss: 0.6383 - val_accuracy: 0.9130
# Epoch 241/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9823
# Epoch 00241: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0479 - accuracy: 0.9823 - val_loss: 0.6225 - val_accuracy: 0.8913
# Epoch 242/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9768
# Epoch 00242: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0523 - accuracy: 0.9768 - val_loss: 0.6102 - val_accuracy: 0.8913
# Epoch 243/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9768
# Epoch 00243: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0477 - accuracy: 0.9768 - val_loss: 0.6409 - val_accuracy: 0.9022
# Epoch 244/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9809
# Epoch 00244: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0494 - accuracy: 0.9809 - val_loss: 0.6264 - val_accuracy: 0.8859
# Epoch 245/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9836
# Epoch 00245: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0459 - accuracy: 0.9836 - val_loss: 0.6123 - val_accuracy: 0.8913
# Epoch 246/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9918
# Epoch 00246: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0297 - accuracy: 0.9918 - val_loss: 0.5985 - val_accuracy: 0.8967
# Epoch 247/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9877
# Epoch 00247: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0360 - accuracy: 0.9877 - val_loss: 0.6047 - val_accuracy: 0.8750
# Epoch 248/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9932
# Epoch 00248: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0316 - accuracy: 0.9932 - val_loss: 0.6666 - val_accuracy: 0.8913
# Epoch 249/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9836
# Epoch 00249: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0415 - accuracy: 0.9836 - val_loss: 0.5739 - val_accuracy: 0.9076
# Epoch 250/250
# 6/6 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9905
# Epoch 00250: val_accuracy did not improve from 0.91304
# 6/6 [==============================] - 16s 3s/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.6624 - val_accuracy: 0.8859
# Training completed in time:  1:06:23.836173

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9618008136749268
# Testing Accuracy:  0.885869562625885

# %%
preds = model.predict(x_test) # label scores 

classpreds = np.argmax(preds, axis=1) # predicted classes 

y_testclass = np.argmax(y_test, axis=1) # true classes

n_classes=6 # number of classes

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']

# %%
# Plot ROC curves
fig, ax = plt.subplots(figsize=(16, 10))
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve for Each Class')
for i in range(n_classes):
    ax.plot(fpr[i], tpr[i], linewidth=3, label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], c_names[i]))
ax.legend(loc="best", fontsize='x-large')
ax.grid(alpha=.4)
sns.despine()
plt.show()

# %%
# Classification Report
print(classification_report(y_testclass, classpreds, target_names=c_names))
# Out:
#                 precision    recall  f1-score   support
#
# Bronchiectasis       1.00      0.33      0.50         3
#  Bronchiolitis       0.25      0.33      0.29         3
#           COPD       0.94      0.99      0.96       159
#        Healthy       0.00      0.00      0.00         7
#      Pneumonia       0.60      0.43      0.50         7
#           URTI       0.17      0.20      0.18         5
#
#       accuracy                           0.89       184
#      macro avg       0.49      0.38      0.41       184
#   weighted avg       0.86      0.89      0.87       184

# %%
# Confusion Matrix
print(confusion_matrix(y_testclass, classpreds))
# Out:
# [[  1   0   2   0   0   0]
#  [  0   1   0   0   0   2]
#  [  0   0 157   0   1   1]
#  [  0   2   3   0   0   2]
#  [  0   0   4   0   3   0]
#  [  0   1   1   1   1   1]]
